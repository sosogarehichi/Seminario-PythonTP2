# %% [markdown]
# # 10. Simulación de partidas y ranking en shooter online
#
#  Simule varias partidas de un juego de disparos y genere un ranking basado en el puntaje
#  total de cada jugador. Se utilizará el siguiente sistema de puntuación:
#
#  Acción       Puntos
#  - Kill:          3
#  - Asistencia:    1
#  - Muerte:       -1
#
# ```
#  Imprima las tablas de resultados luego de la inserción de cada una de las rondas pudiendo
#  ver el progreso en el equipo.
#  Además cada ronda debe tener un MVP (Mejor Jugador del Partido/ronda) basado en su
#  puntuación. La cantidad de veces que el jugador ha sido MVP también se debe contabilizar
#  Se debe imprimir el total de kills, asistencias, muertes, cantidad de MVP y puntos totales. La
#  tabla tienen que estar en orden decreciente por los puntos totales.
#  ```

# %%
from src.funciones import *

rounds = [
 {
 'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
 'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
 'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
 'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
 'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
 'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
 'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
 'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
 'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
 'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
 'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
 'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
 'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
 'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
 'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
 'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
 'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
 }
]

# diccionario nuevo para llevar los rankings
player_stats = {}

# contador para las rondas
i = 0
for round in rounds:
    # cada ronda reiniciar
    best_kda = -1
    mvp_player = None
    print()
    i += 1
    # se imprime titulo de cada ronda
    print(print_round("ronda", i))

    for player in round:

        # calcular KDA de cada player
        death = 1 if round[player]['deaths'] else 0
        kda = calculate_points(round[player]['kills'], round[player]['assists'], death)

        if player not in player_stats:
            # cargar nuevo jugador
            load_player(player_stats, round, player, death, kda)
        else:
            # actualizar estadisticas
            update_player(player, player_stats, round, death, kda)
        # determinar MVP por el kda
        best_kda, mvp_player = who_is_mvp(best_kda, kda, mvp_player, player)
    
    # finaliza la ronda y se actualiza MVP
    player_stats[mvp_player]['MVPs'] += 1

    # ordenar jugadores
    players_in_order = dict(sorted(player_stats.items(), key=lambda x: x[1]['points'], reverse=True))

    # imprime el ranking de jugadores ordenados
    for players in players_in_order:
        print(print_player(players, players_in_order[players]))  
    # imprime el MVP
    print(str(f"✰ MVP de la partida: {mvp_player} ✰").center(72))
    
# espacios en blanco para legibilidad
print()
print()
# se imprime el ranking final
print(print_round("final", ""))
for players in players_in_order:
        print(print_player(players, players_in_order[players]))
# Out:
# Ranking ronda: 1
# Jugador      Kills       Asistencias      Muertes      MVPs      Puntaje
# ────────────────────────────────────────────────────────────────────────
# Shadow         2             1              1           1          6
# ╰───────────────────────────────────────────────────────────────────────
# Viper          1             2              1           0          4
# ╰───────────────────────────────────────────────────────────────────────
# Reaper         1             1              0           0          4
# ╰───────────────────────────────────────────────────────────────────────
# Blaze          1             0              0           0          3
# ╰───────────────────────────────────────────────────────────────────────
# Frost          0             1              0           0          1
# ╰───────────────────────────────────────────────────────────────────────
#                      ✰ MVP de la partida: Shadow ✰
#
# Ranking ronda: 2
# ...
